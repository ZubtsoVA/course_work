# %%
import os


# !git clone https://github.com/ZubtsoVA/course_work.git


if os.path.exists('/content/course_work'):
    os.chdir('/content/course_work')
    # !git pull
else:
    # !git clone https://github.com/ZubtsoVA/course_work.git
    os.chdir('/content/course_work')


# !pip install -r requirements.txt
# Out:
# fatal: destination path 'course_work' already exists and is not an empty directory.
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 451 bytes | 150.00 KiB/s, done.
# From https://github.com/ZubtsoVA/course_work
#    7f0eabe..3fe6113  main       -> origin/main
# Updating 7f0eabe..3fe6113
# Fast-forward
#  main.py | 20 +++++++++++++-------
#  1 file changed, 13 insertions(+), 7 deletions(-)
# Requirement already satisfied: contourpy==1.3.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (1.3.3)
# Requirement already satisfied: cycler==0.12.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: filelock==3.25.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (3.25.0)
# Requirement already satisfied: fonttools==4.61.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (4.61.1)
# Requirement already satisfied: fsspec==2026.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (2026.2.0)
# Requirement already satisfied: Jinja2==3.1.6 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: kiwisolver==1.4.9 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (1.4.9)
# Requirement already satisfied: MarkupSafe==3.0.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (3.0.3)
# Requirement already satisfied: matplotlib==3.10.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (3.10.8)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: networkx==3.6.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (3.6.1)
# Requirement already satisfied: numpy==2.4.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (2.4.2)
# Requirement already satisfied: packaging==26.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (26.0)
# Requirement already satisfied: pillow==12.1.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (12.1.1)
# Requirement already satisfied: pyparsing==3.3.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (3.3.2)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (2.9.0.post0)
# Requirement already satisfied: scipy==1.17.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (1.17.1)
# Requirement already satisfied: setuptools==82.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 18)) (82.0.0)
# Requirement already satisfied: six==1.17.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 19)) (1.17.0)
# Requirement already satisfied: sympy==1.14.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (1.14.0)
# Requirement already satisfied: torch==2.4.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 21)) (2.4.1)
# Requirement already satisfied: torch-directml==0.2.5.dev240914 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 22)) (0.2.5.dev240914)
# Requirement already satisfied: torchvision==0.19.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 23)) (0.19.1)
# Requirement already satisfied: typing_extensions==4.15.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 24)) (4.15.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1->-r requirements.txt (line 21)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1->-r requirements.txt (line 21)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1->-r requirements.txt (line 21)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1->-r requirements.txt (line 21)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1->-r requirements.txt (line 21)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1->-r requirements.txt (line 21)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1->-r requirements.txt (line 21)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1->-r requirements.txt (line 21)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1->-r requirements.txt (line 21)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1->-r requirements.txt (line 21)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1->-r requirements.txt (line 21)) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1->-r requirements.txt (line 21)) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.1->-r requirements.txt (line 21)) (12.9.86)

# %%
# !python main.py
# Out:
# [Colab] GPU не найден, используется CPU
# Using device: cpu
# Total trainable parameters: 1,949,409
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Training PI‑CNN for Black–Scholes
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/lr_scheduler.py:232: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch    1 | Loss 3.01e+01 | PDE 2.94e+01 | Smax 6.25e-02 | T 3.00e-03 | S0 0.00e+00 | LR 9.99e-04
