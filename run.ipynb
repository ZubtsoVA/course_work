# %%
import os


# !git clone https://github.com/ZubtsoVA/course_work.git


os.chdir('/content/course_work')


# !pip install -r requirements.txt
# Out:
# Cloning into 'course_work'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 23 (delta 9), reused 15 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (23/23), 12.26 KiB | 241.00 KiB/s, done.
# Resolving deltas: 100% (9/9), done.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2874/1072424986.py in <cell line: 0>()
#       5
#       6
# ----> 7 os.chdir('/content/ZubtsoVA/course_work')
#       8
#       9
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/ZubtsoVA/course_work'
